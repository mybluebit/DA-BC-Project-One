# %%
# # Consumers know
#     The Price
#     The Professional Rating
#     The taste
# # Wine tasters
#     The score given by the tasters effects the price

# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
from scipy.stats import linregress
from sklearn import datasets
from sklearn import linear_model
import statsmodels.api as sm

# %%
#Imported 4 sets of data
vivino_file_red = "red_wine_0to400_anyrating.csv"
vivino_file_sparkling = "sparkling_wine_0to400_anyrating.csv"
vivino_file_white = "white_wine_0to400_anyrating (1).csv"
winemag_file = "winemag-data-130k-v2.csv"
winemag_file_df = pd.read_csv(winemag_file)
vivino_file_red_df = pd.read_csv(vivino_file_red)
vivino_file_sparkling_df = pd.read_csv(vivino_file_sparkling)
vivino_file_white_df = pd.read_csv(vivino_file_white)

# %%
# merged red&white&sparkling and dropped NA values and got rid of Unnamed 0
vivino_merged_df = vivino_file_red_df.append(vivino_file_white_df)
vivino_merged_df = vivino_merged_df.append(vivino_file_sparkling_df)
vivino_merged_df
# Out:
#       Unnamed: 0                                        Name Rating  \
# 0              0        Cobos Marchiori Vineyard Malbec 2015    4.8
# 1              1  Adrianna Vineyard River Stones Malbec 2015    4.8
# 2              2           Darius II Cabernet Sauvignon 2016    4.8
# 3              3                Saint-Émilion Grand Cru 2014    4.8
# 4              4              Fortis Cabernet Sauvignon 2014    4.8
# ...          ...                                         ...    ...
# 1961        1961         La Grande Année Brut Champagne 2004    4.5
# 1962        1962                         Brut Champagne 2005    4.5
# 1963        1963          La Grande Dame Brut Champagne 2006    4.5
# 1964        1964          La Grande Dame Brut Champagne 2004    4.5
# 1965        1965                         J. Schram Brut 2000    4.6
#
#            Price NumberOfRatings        Country                    Winery
# 0        $223.99     669 ratings      Argentina                Viña Cobos
# 1        $173.99     190 ratings      Argentina             Catena Zapata
# 2        $324.99     104 ratings  United States                  Darioush
# 3        $183.99      98 ratings         France  Château Tertre Roteboeuf
# 4        $299.99      91 ratings  United States                Pine Ridge
# ...          ...             ...            ...                       ...
# 1961  View shops    3097 ratings         France                 Bollinger
# 1962  View shops    2981 ratings         France              Dom Pérignon
# 1963  View shops    2689 ratings         France            Veuve Clicquot
# 1964  View shops    2338 ratings         France            Veuve Clicquot
# 1965  View shops      25 ratings  United States               Schramsberg
#
# [5898 rows x 7 columns]

# %%
vivino_merged_df = vivino_merged_df.drop(['Unnamed: 0'], axis=1)
vivino_merged_df
# Out:
#                                             Name Rating       Price  \
# 0           Cobos Marchiori Vineyard Malbec 2015    4.8     $223.99
# 1     Adrianna Vineyard River Stones Malbec 2015    4.8     $173.99
# 2              Darius II Cabernet Sauvignon 2016    4.8     $324.99
# 3                   Saint-Émilion Grand Cru 2014    4.8     $183.99
# 4                 Fortis Cabernet Sauvignon 2014    4.8     $299.99
# ...                                          ...    ...         ...
# 1961         La Grande Année Brut Champagne 2004    4.5  View shops
# 1962                         Brut Champagne 2005    4.5  View shops
# 1963          La Grande Dame Brut Champagne 2006    4.5  View shops
# 1964          La Grande Dame Brut Champagne 2004    4.5  View shops
# 1965                         J. Schram Brut 2000    4.6  View shops
#
#      NumberOfRatings        Country                    Winery
# 0        669 ratings      Argentina                Viña Cobos
# 1        190 ratings      Argentina             Catena Zapata
# 2        104 ratings  United States                  Darioush
# 3         98 ratings         France  Château Tertre Roteboeuf
# 4         91 ratings  United States                Pine Ridge
# ...              ...            ...                       ...
# 1961    3097 ratings         France                 Bollinger
# 1962    2981 ratings         France              Dom Pérignon
# 1963    2689 ratings         France            Veuve Clicquot
# 1964    2338 ratings         France            Veuve Clicquot
# 1965      25 ratings  United States               Schramsberg
#
# [5898 rows x 6 columns]

# %%
vivino_merged_df = vivino_merged_df.dropna()
vivino_merged_df.head()
# Out:
#                                          Name Rating    Price NumberOfRatings  \
# 0        Cobos Marchiori Vineyard Malbec 2015    4.8  $223.99     669 ratings
# 1  Adrianna Vineyard River Stones Malbec 2015    4.8  $173.99     190 ratings
# 2           Darius II Cabernet Sauvignon 2016    4.8  $324.99     104 ratings
# 3                Saint-Émilion Grand Cru 2014    4.8  $183.99      98 ratings
# 4              Fortis Cabernet Sauvignon 2014    4.8  $299.99      91 ratings
#
#          Country                    Winery
# 0      Argentina                Viña Cobos
# 1      Argentina             Catena Zapata
# 2  United States                  Darioush
# 3         France  Château Tertre Roteboeuf
# 4  United States                Pine Ridge

# %%
# removed unnamed column and replaced United States with US
vivino_merged_df["Country"]= vivino_merged_df["Country"].replace("United States", "US")
vivino_merged_df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                             Name Rating       Price  \
# 0           Cobos Marchiori Vineyard Malbec 2015    4.8     $223.99
# 1     Adrianna Vineyard River Stones Malbec 2015    4.8     $173.99
# 2              Darius II Cabernet Sauvignon 2016    4.8     $324.99
# 3                   Saint-Émilion Grand Cru 2014    4.8     $183.99
# 4                 Fortis Cabernet Sauvignon 2014    4.8     $299.99
# ...                                          ...    ...         ...
# 1961         La Grande Année Brut Champagne 2004    4.5  View shops
# 1962                         Brut Champagne 2005    4.5  View shops
# 1963          La Grande Dame Brut Champagne 2006    4.5  View shops
# 1964          La Grande Dame Brut Champagne 2004    4.5  View shops
# 1965                         J. Schram Brut 2000    4.6  View shops
#
#      NumberOfRatings    Country                    Winery
# 0        669 ratings  Argentina                Viña Cobos
# 1        190 ratings  Argentina             Catena Zapata
# 2        104 ratings         US                  Darioush
# 3         98 ratings     France  Château Tertre Roteboeuf
# 4         91 ratings         US                Pine Ridge
# ...              ...        ...                       ...
# 1961    3097 ratings     France                 Bollinger
# 1962    2981 ratings     France              Dom Pérignon
# 1963    2689 ratings     France            Veuve Clicquot
# 1964    2338 ratings     France            Veuve Clicquot
# 1965      25 ratings         US               Schramsberg
#
# [5886 rows x 6 columns]

# %%
#Remove " View Shop" prices
vivino_merged_df= vivino_merged_df[vivino_merged_df.Price.str.contains("View shops") == False]
vivino_merged_df
# Out:
#                                             Name Rating    Price  \
# 0           Cobos Marchiori Vineyard Malbec 2015    4.8  $223.99
# 1     Adrianna Vineyard River Stones Malbec 2015    4.8  $173.99
# 2              Darius II Cabernet Sauvignon 2016    4.8  $324.99
# 3                   Saint-Émilion Grand Cru 2014    4.8  $183.99
# 4                 Fortis Cabernet Sauvignon 2014    4.8  $299.99
# ...                                          ...    ...      ...
# 1864                      American Spumante N.V.    3.0    $5.99
# 1865                              Cava Brut N.V.    2.9   $24.99
# 1866       Extra Dry (California Champagne) N.V.    2.8    $6.95
# 1867                American Champagne Brut N.V.    2.7    $4.99
# 1868           American Champagne Extra Dry N.V.    2.4    $4.99
#
#      NumberOfRatings    Country                    Winery
# 0        669 ratings  Argentina                Viña Cobos
# 1        190 ratings  Argentina             Catena Zapata
# 2        104 ratings         US                  Darioush
# 3         98 ratings     France  Château Tertre Roteboeuf
# 4         91 ratings         US                Pine Ridge
# ...              ...        ...                       ...
# 1864     199 ratings         US                  J. Roget
# 1865      28 ratings      Spain                      Elvi
# 1866     393 ratings         US                    Cook's
# 1867     884 ratings         US                  J. Roget
# 1868     121 ratings         US                  J. Roget
#
# [5783 rows x 6 columns]

# %%
#remove"$"
vivino_merged_df['Price'] = vivino_merged_df['Price'].str.replace('$','')
vivino_merged_df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                             Name Rating   Price  \
# 0           Cobos Marchiori Vineyard Malbec 2015    4.8  223.99
# 1     Adrianna Vineyard River Stones Malbec 2015    4.8  173.99
# 2              Darius II Cabernet Sauvignon 2016    4.8  324.99
# 3                   Saint-Émilion Grand Cru 2014    4.8  183.99
# 4                 Fortis Cabernet Sauvignon 2014    4.8  299.99
# ...                                          ...    ...     ...
# 1864                      American Spumante N.V.    3.0    5.99
# 1865                              Cava Brut N.V.    2.9   24.99
# 1866       Extra Dry (California Champagne) N.V.    2.8    6.95
# 1867                American Champagne Brut N.V.    2.7    4.99
# 1868           American Champagne Extra Dry N.V.    2.4    4.99
#
#      NumberOfRatings    Country                    Winery
# 0        669 ratings  Argentina                Viña Cobos
# 1        190 ratings  Argentina             Catena Zapata
# 2        104 ratings         US                  Darioush
# 3         98 ratings     France  Château Tertre Roteboeuf
# 4         91 ratings         US                Pine Ridge
# ...              ...        ...                       ...
# 1864     199 ratings         US                  J. Roget
# 1865      28 ratings      Spain                      Elvi
# 1866     393 ratings         US                    Cook's
# 1867     884 ratings         US                  J. Roget
# 1868     121 ratings         US                  J. Roget
#
# [5783 rows x 6 columns]

# %%
vivino = vivino_merged_df[vivino_merged_df.Price.str.contains("ratings") == False]
vivino
# Out:
#                                             Name Rating   Price  \
# 0           Cobos Marchiori Vineyard Malbec 2015    4.8  223.99
# 1     Adrianna Vineyard River Stones Malbec 2015    4.8  173.99
# 2              Darius II Cabernet Sauvignon 2016    4.8  324.99
# 3                   Saint-Émilion Grand Cru 2014    4.8  183.99
# 4                 Fortis Cabernet Sauvignon 2014    4.8  299.99
# ...                                          ...    ...     ...
# 1864                      American Spumante N.V.    3.0    5.99
# 1865                              Cava Brut N.V.    2.9   24.99
# 1866       Extra Dry (California Champagne) N.V.    2.8    6.95
# 1867                American Champagne Brut N.V.    2.7    4.99
# 1868           American Champagne Extra Dry N.V.    2.4    4.99
#
#      NumberOfRatings    Country                    Winery
# 0        669 ratings  Argentina                Viña Cobos
# 1        190 ratings  Argentina             Catena Zapata
# 2        104 ratings         US                  Darioush
# 3         98 ratings     France  Château Tertre Roteboeuf
# 4         91 ratings         US                Pine Ridge
# ...              ...        ...                       ...
# 1864     199 ratings         US                  J. Roget
# 1865      28 ratings      Spain                      Elvi
# 1866     393 ratings         US                    Cook's
# 1867     884 ratings         US                  J. Roget
# 1868     121 ratings         US                  J. Roget
#
# [5755 rows x 6 columns]

# %%
vivino["Price"].unique()
# Out:
# array(['223.99', '173.99', '324.99', '183.99', '299.99', '335.99',
#        '349.97', '389.99', '186.98', '388.88', '119.85', '219.94',
#        '249.99', '399.99', '285.99', '399', '299', '135', '300', '65.99',
#        '338', '359.99', '241.99', '269.95', '174.88', '270', '400',
#        '214.99', '274.99', '319', '309.97', '299.97', '374.99', '199.99',
#        '189', '219.95', '369.99', '159.95', '384.99', '304', '239',
#        '329.97', '329.99', '289.99', '169.95', '174.89', '205.99', '285',
#        '109', '125', '279.99', '289.97', '299.95', '315', '129', '164.99',
#        '240', '281.99', '349.95', '241.98', '289', '209', '169.90',
#        '219.99', '119.99', '189.97', '224.95', '172', '174.99', '195.99',
#        '349.99', '179.99', '225', '109.75', '224.99', '179', '151.99',
#        '129.99', '275', '360', '195.95', '199', '259.99', '399.95',
#        '139.95', '245', '59.99', '124.99', '149.94', '319.97', '169.99',
#        '184.99', '104.99', '159.99', '316', '99.99', '199.95', '94.90',
#        '249.97', '149', '330', '142.99', '159.48', '79.15', '263.99',
#        '169', '175.99', '197.98', '197.99', '109.98', '134.99', '280.48',
#        '388', '164.98', '399.97', '274.98', '329.95', '252.99', '299.98',
#        '247.48', '127.99', '269.99', '319.99', '209.99', '44.99', '84.99',
#        '153.98', '133.99', '170.99', '307.98', '174.90', '109.89',
#        '119.93', '389', '179.95', '159', '129.95', '153.99', '344.99',
#        '137.95', '139.99', '134.98', '205', '164.91', '325', '263.98',
#        '230.98', '254.99', '124.95', '220', '167.99', '307.95', '244.98',
#        '99.98', '172.99', '294.99', '290', '149.99', '185', '309.98',
#        '99', '109.90', '119.88', '99.95', '165', '247.03', '119.98',
#        '239.99', '195', '114.95', '379.99', '229.98', '303.99', '259',
#        '64.95', '194.99', '74.98', '79.95', '249.95', '235', '109.99',
#        '250', '132.95', '247.97', '296.99', '329', '60.99', '114.99',
#        '112.99', '190', '119.95', '174.97', '87', '139.97', '119',
#        '239.95', '89.95', '229', '94.99', '294.96', '115', '247.99',
#        '219.97', '139', '144.99', '215', '224.94', '89.99', '97.99',
#        '186', '204.99', '137.49', '329.98', '138.99', '294.98', '132.99',
#        '219.98', '215.99', '367', '168', '149.95', '269.97', '69.99',
#        '59.50', '227.99', '365', '229.99', '212.99', '89', '120.99',
#        '129.98', '199.98', '111.99', '98.99', '224.90', '131.99', '79.99',
#        '161.90', '159.97', '180', '159.98', '66.99', '229.95', '191',
#        '92.99', '38.95', '29.91', '120.98', '69.73', '37.99', '29.99',
#        '99.96', '84.85', '115.49', '123.99', '113.99', '186.99', '48',
#        '181.49', '131.98', '68.99', '98.98', '74.54', '126.48', '86.88',
#        '75.95', '189.95', '101.99', '234.99', '399.96', '271.99', '350',
#        '25.95', '27', '120', '54', '47.95', '39.83', '29', '44.97',
#        '121.99', '37.45', '50.34', '39.93', '15.19', '62.94', '57.95',
#        '50.38', '18.98', '23.98', '24', '13.89', '17.98', '11.97',
#        '17.46', '31.48', '16.93', '19.98', '24.35', '22', '8.95', '21.47',
#        '9.95', '10.96', '15.93', '16.94', '10.49', '14.97', '13', '38.97',
#        '33.55', '10.97', '36', '19.85', '6.91', '5.99', '15.88', '7.95',
#        '10.98', '12.47', '22.98', '5.49', '10.79', '13.49', '6.95',
#        '4.99'], dtype=object)

# %%
# Convert price to integer
# vivino['Rating'] = pd.to_numeric(vivino['Rating'])
# vivino.astype({'Price': 'int32'}).dtypes
# pd.to_numeric(vivino["Price"], downcast='float')
# vivino['Rating'].astype(str).astype(float)
vivino["Rating"] = vivino["Rating"].map(float)
vivino["Price"] = vivino["Price"].map(float)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
vivino.head()
# Out:
#                                          Name  Rating   Price NumberOfRatings  \
# 0        Cobos Marchiori Vineyard Malbec 2015     4.8  223.99     669 ratings
# 1  Adrianna Vineyard River Stones Malbec 2015     4.8  173.99     190 ratings
# 2           Darius II Cabernet Sauvignon 2016     4.8  324.99     104 ratings
# 3                Saint-Émilion Grand Cru 2014     4.8  183.99      98 ratings
# 4              Fortis Cabernet Sauvignon 2014     4.8  299.99      91 ratings
#
#      Country                    Winery
# 0  Argentina                Viña Cobos
# 1  Argentina             Catena Zapata
# 2         US                  Darioush
# 3     France  Château Tertre Roteboeuf
# 4         US                Pine Ridge

# %%
#Multiply rating by 20
vivino["Rating"] = 20 * vivino["Rating"]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
bins = [0,20,40,60,80,100,120,140,160,180,200,220,240,260,280,300,320,340,360,380,400]
group_names = ["Below $20", "$20-40","40-$60", "$60-$80","$80-$100","$100-$120","$120-140","$140-$160","$160-$180","$180-$200","$200-$220","$220-$240","$240-$260","$260-$280","$280-$300","$300-$320","$320-$340","$340-$360","$360-$380","$380-$400"]

# %%
vivino["Group"] = pd.cut(vivino["Price"], bins, labels=group_names)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
vivino = vivino.rename(columns={ "Rating": "Mean Consumer Rating", "Price" : "Mean Consumer Prices"})
vivino_mean_group = vivino.groupby(["Group"]).mean()
# vivino_mean_country = vivino.groupby(['Country','Group']).mean()
vivino_mean_group
# Out:
#            Mean Consumer Rating  Mean Consumer Prices
# Group
# Below $20             75.862069             15.293458
# $20-40                79.986766             30.107535
# 40-$60                83.008092             50.726902
# $60-$80               85.057576             71.642803
# $80-$100              87.037975             92.188502
# $100-$120             88.078740            112.002087
# $120-140              88.612245            131.506582
# $140-$160             88.926554            151.165763
# $160-$180             90.091429            172.755486
# $180-$200             89.874126            194.277902
# $200-$220             90.250000            214.857812
# $220-$240             90.341463            230.982317
# $240-$260             90.090909            250.660303
# $260-$280             90.840000            272.426400
# $280-$300             91.119048            295.206190
# $300-$320             91.692308            313.948462
# $320-$340             90.650000            329.937750
# $340-$360             91.073171            352.548049
# $360-$380             90.086957            372.858261
# $380-$400             91.358491            396.022075

# %%
#Drop NA
# filter columns to Country, rating and price
#Rename columns
#Convert data if needed
winemag = winemag_file_df
# winemag = winemag["price"].dropna()
winemag = winemag.dropna(subset=['price'])
# winemag = winemag.dropna(how='any')
winemag = winemag.drop(['Unnamed: 0'], axis=1)
winemag = winemag.rename(columns={"country": "Country", "points": "Professional Rating", "price" : "Wine Mag Prices"})
winemag
# Out:
#          Country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# 5          Spain  Blackberry and raspberry aromas show a typical...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  Professional Rating  \
# 1                                     Avidagos                   87
# 2                                          NaN                   87
# 3                         Reserve Late Harvest                   87
# 4           Vintner's Reserve Wild Child Block                   87
# 5                                 Ars In Vitro                   87
# ...                                        ...                  ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese                   90
# 129967                                     NaN                   90
# 129968                                   Kritt                   90
# 129969                                     NaN                   90
# 129970           Lieu-dit Harth Cuvée Caroline                   90
#
#         Wine Mag Prices        province             region_1  \
# 1                  15.0           Douro                  NaN
# 2                  14.0          Oregon    Willamette Valley
# 3                  13.0        Michigan  Lake Michigan Shore
# 4                  65.0          Oregon    Willamette Valley
# 5                  15.0  Northern Spain              Navarra
# ...                 ...             ...                  ...
# 129966             28.0           Mosel                  NaN
# 129967             75.0          Oregon               Oregon
# 129968             30.0          Alsace               Alsace
# 129969             32.0          Alsace               Alsace
# 129970             21.0          Alsace               Alsace
#
#                  region_2         taster_name taster_twitter_handle  \
# 1                     NaN          Roger Voss            @vossroger
# 2       Willamette Valley        Paul Gregutt           @paulgwine
# 3                     NaN  Alexander Peartree                   NaN
# 4       Willamette Valley        Paul Gregutt           @paulgwine
# 5                     NaN   Michael Schachner           @wineschach
# ...                   ...                 ...                   ...
# 129966                NaN  Anna Lee C. Iijima                   NaN
# 129967       Oregon Other        Paul Gregutt           @paulgwine
# 129968                NaN          Roger Voss            @vossroger
# 129969                NaN          Roger Voss            @vossroger
# 129970                NaN          Roger Voss            @vossroger
#
#                                                     title             variety  \
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 5       Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# ...                                                   ...                 ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...            Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)          Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...      Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)          Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...      Gewürztraminer
#
#                                           winery
# 1                            Quinta dos Avidagos
# 2                                      Rainstorm
# 3                                     St. Julian
# 4                                   Sweet Cheeks
# 5                                         Tandem
# ...                                          ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                  Citation
# 129968                           Domaine Gresser
# 129969                      Domaine Marcel Deiss
# 129970                          Domaine Schoffit
#
# [120975 rows x 13 columns]

# %%
bins = [0,20,40,60,80,100,120,140,160,180,200,220,240,260,280,300,320,340,360,380,400]
group_names = ["Below $20", "$20-40","40-$60", "$60-$80","$80-$100","$100-$120","$120-140","$140-$160","$160-$180","$180-$200","$200-$220","$220-$240","$240-$260","$260-$280","$280-$300","$300-$320","$320-$340","$340-$360","$360-$380","$380-$400"]
winemag["Group"] = pd.cut(winemag["Wine Mag Prices"], bins, labels=group_names)

# %%
winemag_mean = winemag.groupby(["Group"]).mean()
winemag_mean = winemag_mean.dropna()
winemag_mean
# Out:
#            Professional Rating  Wine Mag Prices
# Group
# Below $20            86.575344        15.071664
# $20-40               88.618383        29.741173
# 40-$60               90.284243        50.239841
# $60-$80              91.121838        70.809101
# $80-$100             91.775551        91.606212
# $100-$120            92.141684       112.314168
# $120-140             92.279302       130.068579
# $140-$160            92.688285       150.694561
# $160-$180            93.140426       172.038298
# $180-$200            93.194872       195.292308
# $200-$220            93.310345       212.758621
# $220-$240            93.317308       230.432692
# $240-$260            94.062500       251.968750
# $260-$280            94.400000       273.625000
# $280-$300            93.764706       295.808824
# $300-$320            94.625000       312.250000
# $320-$340            94.080000       327.560000
# $340-$360            94.677419       352.387097
# $360-$380            94.666667       371.523810
# $380-$400            94.321429       397.285714

# %%
#On average wine cellar 
merged_df= pd.merge(vivino_mean_group, winemag_mean, on="Group")
merged_df
# Out:
#            Mean Consumer Rating  Mean Consumer Prices  Professional Rating  \
# Group
# Below $20             75.862069             15.293458            86.575344
# $20-40                79.986766             30.107535            88.618383
# 40-$60                83.008092             50.726902            90.284243
# $60-$80               85.057576             71.642803            91.121838
# $80-$100              87.037975             92.188502            91.775551
# $100-$120             88.078740            112.002087            92.141684
# $120-140              88.612245            131.506582            92.279302
# $140-$160             88.926554            151.165763            92.688285
# $160-$180             90.091429            172.755486            93.140426
# $180-$200             89.874126            194.277902            93.194872
# $200-$220             90.250000            214.857812            93.310345
# $220-$240             90.341463            230.982317            93.317308
# $240-$260             90.090909            250.660303            94.062500
# $260-$280             90.840000            272.426400            94.400000
# $280-$300             91.119048            295.206190            93.764706
# $300-$320             91.692308            313.948462            94.625000
# $320-$340             90.650000            329.937750            94.080000
# $340-$360             91.073171            352.548049            94.677419
# $360-$380             90.086957            372.858261            94.666667
# $380-$400             91.358491            396.022075            94.321429
#
#            Wine Mag Prices
# Group
# Below $20        15.071664
# $20-40           29.741173
# 40-$60           50.239841
# $60-$80          70.809101
# $80-$100         91.606212
# $100-$120       112.314168
# $120-140        130.068579
# $140-$160       150.694561
# $160-$180       172.038298
# $180-$200       195.292308
# $200-$220       212.758621
# $220-$240       230.432692
# $240-$260       251.968750
# $260-$280       273.625000
# $280-$300       295.808824
# $300-$320       312.250000
# $320-$340       327.560000
# $340-$360       352.387097
# $360-$380       371.523810
# $380-$400       397.285714

# %%
merged_df = merged_df.reset_index('Group')

# %%
plt.plot(merged_df["Mean Consumer Prices"],merged_df["Mean Consumer Rating"], color="green", label="Mean Consumer Rating")
plt.plot(merged_df["Mean Consumer Prices"],merged_df["Professional Rating"], color="blue", label="Mean Professional Rating")
plt.legend(loc="best")
plt.title("Comps")
plt.xlabel("Price Bins")
plt.ylabel("Ratings")
# Out:
# Text(0, 0.5, 'Ratings')

# %%
# In what way does consumer rating depend on prices?
y_values = vivino["Mean Consumer Rating"]
x_values = vivino["Mean Consumer Prices"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.6554337538059041

# %%
# In what way does price depend on professional rating?
x_values =winemag["Professional Rating"]
y_values = winemag["Wine Mag Prices"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.4161667418606225

# %%
#Lets look at in what way does price depend on professional rating in wines under $100?
filtered_winemag_df = winemag.loc[winemag["Wine Mag Prices"] < 100]
x_values = filtered_winemag_df["Professional Rating"]
y_values = filtered_winemag_df["Wine Mag Prices"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")
plt.xlabel('Professional Rating')
plt.show()
# Out:
# The r-squared is: 0.5470680050253198
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-158-58dcc16c9509> in <module>
#      10 plt.annotate(line_eq,(6,10),fontsize=15,color="red")
#      11 print(f"The r-squared is: {rvalue}")
# ---> 12 plt.xlabel('Professional Rating')
#      13 plt.show()
#
# TypeError: 'str' object is not callable

# %%
X = merged_df[['Professional Rating','Wine Mag Prices']] # here we have 2 variables for multiple regression. If you just want to use one variable for simple linear regression, then use X = df['Interest_Rate'] for example.Alternatively, you may add additional variables within the brackets
Y = merged_df['Mean Consumer Rating']
 
# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)

# prediction with sklearn
New_Professional_Rating = 90
New_Wine_Mag_Prices = 23
print ('Predicted Consumer Rating: \n', regr.predict([[New_Professional_Rating ,New_Wine_Mag_Prices]]))

# with statsmodels
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# Intercept:
#  -123.57458059640558
# Coefficients:
#  [ 2.30298264 -0.00791438]
# Predicted Consumer Rating:
#  [83.51182609]
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Mean Consumer Rating   R-squared:                       0.971
# Model:                              OLS   Adj. R-squared:                  0.968
# Method:                   Least Squares   F-statistic:                     287.9
# Date:                  Wed, 18 Mar 2020   Prob (F-statistic):           7.74e-14
# Time:                          16:37:40   Log-Likelihood:                -20.980
# No. Observations:                    20   AIC:                             47.96
# Df Residuals:                        17   BIC:                             50.95
# Df Model:                             2
# Covariance Type:              nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                -123.5746     14.951     -8.265      0.000    -155.118     -92.031
# Professional Rating     2.3030      0.167     13.784      0.000       1.950       2.655
# Wine Mag Prices        -0.0079      0.003     -2.634      0.017      -0.014      -0.002
# ==============================================================================
# Omnibus:                        1.530   Durbin-Watson:                   1.768
# Prob(Omnibus):                  0.465   Jarque-Bera (JB):                1.137
# Skew:                          -0.349   Prob(JB):                        0.566
# Kurtosis:                       2.063   Cond. No.                     2.21e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.21e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
merged_df
# Out:
#         Group  Mean Consumer Rating  Mean Consumer Prices  \
# 0   Below $20             75.862069             15.293458
# 1      $20-40             79.986766             30.107535
# 2      40-$60             83.008092             50.726902
# 3     $60-$80             85.057576             71.642803
# 4    $80-$100             87.037975             92.188502
# 5   $100-$120             88.078740            112.002087
# 6    $120-140             88.612245            131.506582
# 7   $140-$160             88.926554            151.165763
# 8   $160-$180             90.091429            172.755486
# 9   $180-$200             89.874126            194.277902
# 10  $200-$220             90.250000            214.857812
# 11  $220-$240             90.341463            230.982317
# 12  $240-$260             90.090909            250.660303
# 13  $260-$280             90.840000            272.426400
# 14  $280-$300             91.119048            295.206190
# 15  $300-$320             91.692308            313.948462
# 16  $320-$340             90.650000            329.937750
# 17  $340-$360             91.073171            352.548049
# 18  $360-$380             90.086957            372.858261
# 19  $380-$400             91.358491            396.022075
#
#     Professional Rating  Wine Mag Prices
# 0             86.575344        15.071664
# 1             88.618383        29.741173
# 2             90.284243        50.239841
# 3             91.121838        70.809101
# 4             91.775551        91.606212
# 5             92.141684       112.314168
# 6             92.279302       130.068579
# 7             92.688285       150.694561
# 8             93.140426       172.038298
# 9             93.194872       195.292308
# 10            93.310345       212.758621
# 11            93.317308       230.432692
# 12            94.062500       251.968750
# 13            94.400000       273.625000
# 14            93.764706       295.808824
# 15            94.625000       312.250000
# 16            94.080000       327.560000
# 17            94.677419       352.387097
# 18            94.666667       371.523810
# 19            94.321429       397.285714

# %%
# In what way does consumer rating depend on professional rating for the wines in the same price range?
y_values =merged_df["Professional Rating"]
x_values = merged_df["Mean Consumer Rating"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.9796035783504634
